# %% [markdown]
# # Face Recognition Challenge
#
# From wikipedia:
#
# > Face detection can be regarded as a specific case of object-class detection. In object-class detection, the task is to find the locations and sizes of all objects in an image that belong to a given class. Examples include upper torsos, pedestrians, and cars.
# Face-detection algorithms focus on the detection of frontal human faces. It is analogous to image detection in which the image of a person is matched bit by bit. Image matches with the image stores in database. Any facial feature changes in the database will invalidate the matching process.
# A reliable face-detection approach based on the genetic algorithm and the eigen-face technique:
# Firstly, the possible human eye regions are detected by testing all the valley regions in the gray-level image. Then the genetic algorithm is used to generate all the possible face regions which include the eyebrows, the iris, the nostril and the mouth corners.
# Each possible face candidate is normalized to reduce both the lighting effect, which is caused by uneven illumination; and the shirring effect, which is due to head movement. The fitness value of each candidate is measured based on its projection on the eigen-faces. After a number of iterations, all the face candidates with a high fitness value are selected for further verification. At this stage, the face symmetry is measured and the existence of the different facial features is verified for each face candidate.
#
# ## Build a code that finds faces in a given picture.
#
# 1. Build an UDF that finds faces in a given picture.
# 2. Apply to 3 different pictures .

# %% [markdown]
# Most of the code obtained from: https://realpython.com/face-recognition-with-python/

# %%
import cv2
import sys
import os
import matplotlib.pyplot as plt

# %%
def find_faces(image_path, cascade_path):
    
    # Create faceCascade
    # Cascade is the series of steps to detect a something, which are run only if previous steps were successful
    # In this case, faceCascade is the series of steps to detect a face, written my someone
    faceCascade = cv2.CascadeClassifier(cascade_path)
    
    # Read the image
    # Function in cv2 to read an image given a path
    image = cv2.imread(image_path)
    
    # Convert to grayscale (to make it a matrix, otherwise it's a tensor and it won't be processed)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # # Detect faces in the image
    # detectMultiScale is the general function to detect things
    faces = faceCascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(30, 30)
    )
    
    # The function returns a list of rectangles in which it believes it found a face 
    #Next, we will loop over where it thinks it found something.
    
    print("Found {0} faces!".format(len(faces)))
    # Draw a rectangle around the faces
    for (x, y, w, h) in faces:
        cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
        
    # Show image
    plt.imshow(image)

# %%
# Get Current working directory
here = os.getcwd()

# %%
# Apply function on the first image
find_faces(here + "/abba.png", here + "/haarcascade_frontalface_default.xml")
# Out:
# Found 4 faces!

# %%
# Apply function on second image
find_faces(here + "/dogs_and_owners.png", here + "/haarcascade_frontalface_default.xml")
# Out:
# Found 3 faces!

# %%
# Apply function on second image
find_faces(here + "/another_dog.png", here + "/haarcascade_frontalface_default.xml")
# Out:
# Found 1 faces!

# %%
# Apply function on second image
find_faces(here + "/many_faces.png", here + "/haarcascade_frontalface_default.xml")
# Out:
# Found 16 faces!

# %%
# Apply function on second image
find_faces(here + "/cartoon.png", here + "/haarcascade_frontalface_default.xml")
# Out:
# Found 17 faces!

# %%
# Apply function on second image
find_faces(here + "/statues.png", here + "/haarcascade_frontalface_default.xml")
# Out:
# Found 6 faces!

# %%
# Apply function on second image
find_faces(here + "/gargoyle.png", here + "/haarcascade_frontalface_default.xml")
# Out:
# Found 3 faces!

# %%
# Apply function on second image
find_faces(here + "/me.png", here + "/haarcascade_frontalface_default.xml")
# Out:
# Found 2 faces!
